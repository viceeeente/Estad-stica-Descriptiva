# %% [markdown]
# # **Formulario Python para MAT4141**

# %% [markdown]
# ### Importar bibliotecas o librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generar un DataFrame de nombre **df_1** a partir de un archivo (Excel o CSV) con base de datos subido al entorno en VSCode

# %%
# Cargar el DataFrame 
df_1 = pd.read_excel('Base_Netflix.xlsx')
df_1
# Out:
#          ID      Tipo                 Título  \
# 0       s47  Película             Safe House
# 1       s82  Película                   Kate
# 2      s136  Película            Cliffhanger
# 3      s142  Película             Extraction
# 4      s229  Película       The November Man
# ...     ...       ...                    ...
# 7090  s1066   TV Show                Slasher
# 7091  s1702   TV Show  American Horror Story
# 7092  s5889   TV Show          Hemlock Grove
# 7093  s6918   TV Show               Hannibal
# 7094  s5264   TV Show            Dark Matter
#
#                                        País   Año   Duración  \
# 0        South Africa, United States, Japan  2012    115 min
# 1                             United States  2021    106 min
# 2       United States, Italy, France, Japan  1993    113 min
# 3     United States, United Kingdom, Canada  2015     82 min
# 4             United States, United Kingdom  2014    108 min
# ...

# %% [markdown]
# ### Agrupar datos en una tabla de frecuencia

# %%
## Codigo para agrupar datos
Categoría = df_1.groupby('Categoría').size()
Categoría
# Out:
# Categoría
# Acción y Aventura        856
# Anime                    173
# Ciencia Ficción           14
# Clásicos                 100
# Comedia                 1266
# Crimen                   358
# Documental               759
# Docuseries               175
# Dramas                  1593
# Horror                   273
# Musical                   15
# Niños                    318
# Películas                165
# Películas familiares     500
# Reality Show              99
# Romántico                 35
# Stand-Up Comedy          334
# Thrillers                 62
# dtype: int64

# %% [markdown]
# ### Tabla de frecuencia puntuales f y h. Variable Ordinal, Nominal y Discreta

# %%
## Codigo para agrupar datos
Categoría = df_1.groupby('Categoría').size()

Tabla_Frecuencia_Categorias = pd.DataFrame({
    'Frecuencia absoluta (f)': Categoría,
    'Frecuencia relativa (%) (h)': round((Categoría / 7095) * 100, 1)
})
Tabla_Frecuencia_Categorias
# Out:
#                       Frecuencia absoluta (f)  Frecuencia relativa (%) (h)
# Categoría
# Acción y Aventura                         856                         12.1
# Anime                                     173                          2.4
# Ciencia Ficción                            14                          0.2
# Clásicos                                  100                          1.4
# Comedia                                  1266                         17.8
# Crimen                                    358                          5.0
# Documental                                759                         10.7
# Docuseries                                175                          2.5
# Dramas                                   1593                         22.5
# Horror                                    273                          3.8
# Musical                                    15                          0.2
# ...

# %% [markdown]
# ### Tabla de frecuencia puntuales y acumuladas (f,h,F y H) Variable Cuantitativa Discreta

# %%
## Codigo para agrupar datos
Categoría = df_1.groupby('Categoría').size()

## Codigo para crear las frecuencias puntuales y acumuladas (f,h,F y H)
Tabla_Frecuencia_Categorias = pd.DataFrame({
    'Frecuencia absoluta (f)': Categoría,
    'Frecuencia absoluta acumulada (F)': Categoría.cumsum(),
    'Frecuencia relativa (%) (h)': round((Categoría / 7095) * 100, 1),
    'Frecuencia relativa acumulada (%) (H)': round((Categoría/7075 * 100),1).cumsum()
})
Tabla_Frecuencia_Categorias
# Out:
#                       Frecuencia absoluta (f)  \
# Categoría
# Acción y Aventura                         856
# Anime                                     173
# Ciencia Ficción                            14
# Clásicos                                  100
# Comedia                                  1266
# Crimen                                    358
# Documental                                759
# Docuseries                                175
# Dramas                                   1593
# Horror                                    273
# Musical                                    15
# Niños                                     318
# Películas                                 165
# Películas familiares                      500
# Reality Show                               99
# Romántico                                  35
# Stand-Up Comedy                           334
# Thrillers                                  62
#
#                       Frecuencia absoluta acumulada (F)  \
# ...

# %% [markdown]
# ### Tabla de frecuencia variable Cuantitativa Continua

# %%
## Tabla de frecuencia Variable Cuantitativa Continua

##  k = Cantidad de intervalos 
##  n = Tamaño de la muestra 
##  d = Cantidad de decimales de los intervalos 

#Crearemos una nueva columna llamada Intervalos_tiempo
df_1['Intervalos_tiempo'] = pd.cut(df_1['Tiempo (en minutos)'], bins = k, include_lowest= True, precision = d)

#Calcularemos la frecuencia absoluta de la variable Intervalos_tiempo
cuenta_intervalos_tiempo = df_1.groupby('Intervalos_tiempo', observed = True).size()



## Asignar las etiquetas de cada frecuencia 
tabla_7 = pd.DataFrame({
    'Frecuencia absoluta (f)': cuenta_intervalos_tiempo,
    'Frecuencia absoluta acumulada (F)': cuenta_intervalos_tiempo.cumsum(),
    'Frecuencia relativa (%) (h)': cuenta_intervalos_tiempo/n * 100,
    'Frecuencia relativa acumulada (%) (H)': (cuenta_intervalos_tiempo/n * 100).cumsum()
})
tabla_7
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tiempo (en minutos)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ### Calcular la cantidad de intervalos variable Cuantitativa Continua

# %%
## La cantidad de intervalos I(n) depende del tamaño de la muestra n
## Modelado por la función I(n)= 1+3.3*Log10(n)
import numpy as np

Cantidad_intervalos = round(1+3.3*np.log10(250))    ## Tamaño de la muestra = 250
print(Cantidad_intervalos)

# %% [markdown]
# ### Gráfico Circular o de torta
# Variable = Nominal, Ordinal, Discreta

# %%
# Importar bibliotecas o librerías
import matplotlib.pyplot as plt
import numpy as np

#Gráfico circular

#Considerar que "tabla" es el nombre de la tabla de frecuencias construida
categorias = tabla.index  #Indices de la tabla
h = tabla['Frecuencia']   #Considerar que "Frecuencia" es el tipo de frecuencia a graficar

#Gráfico
fig,ax = plt.subplots(figsize = (6,4)) #Tamaño de la figura
circular = ax.pie(h, labels = categorias, autopct= '%.1f%%')

#Personalización
ax.set_title('Título del gráfico')

plt.show()

# %% [markdown]
# ### Gráfico de barras (Columnas)
# Variable = Nominal, Ordinal, Discreta

# %%
#Gráfico de barras (Columnas)

#Considerar que "tabla" es el nombre de la tabla de frecuencias construida

# Importar bibliotecas o librerías
import matplotlib.pyplot as plt
import numpy as np

#Variables
categorias = tabla.index
f = tabla['Frecuencia']   #Considerar que "Frecuencia" es el tipo de frecuencia a graficar

#Gráfico
fig, ax = plt.subplots(figsize = (6,6))
barras = ax.bar(categorias, f, color = 'r', edgecolor ='black') #Los colores son de libre elección

#Personalización
ax.set_title('Título del gráfico')
ax.set_xlabel('Título eje x')
ax.set_ylabel('Título eje y')
ax.bar_label(barras)
plt.xticks(rotation=45) #Rota en 45° las categorías para evitar la superposición
plt.show()

# %% [markdown]
# ### Gráfico de barras
# Variable = Nominal, Ordinal, Discreta

# %%
#Gráfico de barras

#Considerar que "tabla" es el nombre de la tabla de frecuencias construida

# Importar bibliotecas o librerías
import matplotlib.pyplot as plt
import numpy as np

#Variables
categorias = tabla.index
f = tabla['Frecuencia']   #Considerar que "Frecuencia" es el tipo de frecuencia a graficar

#Gráfico
fig, ax = plt.subplots(figsize = (6,6))
barras = ax.barh(categorias, f, color = 'r', edgecolor ='black') #Los colores son de libre elección

#Personalización
ax.set_title('Título del gráfico')
ax.set_xlabel('Título eje y')
ax.set_ylabel('Título eje x')
ax.bar_label(barras)
plt.xticks(rotation=45) #Rota en 45° las categorías para evitar la superposición
plt.show()

# %%
#Histograma

#Considerar que "tabla" es el nombre de la tabla de frecuencias construida

# Importar bibliotecas o librerías
import matplotlib.pyplot as plt
import numpy as np

#Variables
categorias = tabla.index
f= tabla['Frecuencia']   #Considerar que "Frecuencia" es el tipo de frecuencia a graficar

#Gráfico
fig, ax = plt.subplots(figsize = (7,5))
histograma= ax.bar(categorias.astype(str), f, color = 'r', edgecolor = 'black', width = 1) #Los colores son de libre elección

#Personalización
ax.set_title('Título del gráfico')
ax.set_xlabel('Título eje x')
ax.set_ylabel('Título eje y')
ax.bar_label(histograma, fmt = '%.1f%%') #El argumento fmt controla la cantidad de decimales a mostrar
plt.xticks(rotation=45, ha = 'right') #Rota en 45° las categorías para evitar la superposición
plt.show()

# %% [markdown]
# ### Medidas de posición y dispersión para una variable cuantitativa

# %%
media = df['Nombre de la variable'].mean()

mediana = df['Nombre de la variable'].median()

moda = df['Nombre de la variable'].mode()

percentil_k = df['Nombre de la variable'].quantile(k) #ingrese el valor "k" en decimal

desviacion_estandar = df['Nombre de la variable'].std()
